# %% [markdown]
# <a href="https://colab.research.google.com/github/dasuntheekshanagit/COMLab/blob/master/COMMATPLOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2D and 3D

# %%
import matplotlib.pyplot as plt
import numpy as np
 
x = np.arange(-1* np.pi, np.pi,0.01)# -pi to pi
y = np.sin(x)
plt.plot(x,y,'g')
plt.show()

# %%
 
x = np.arange(-1* np.pi, np.pi,0.3)# -pi to pi
y = np.sin(x)
plt.plot(x,y,'ro--') # marker 
plt.title('y = sin(x)',{'fontsize':20,'color':'w'})
plt.grid()
plt.legend(['Sin(x)'])
plt.xlabel('x')
plt.show()

# %% [markdown]
# #Semi-Log and Log-Log 2D plot

# %%
x = [10**x for x in range(0,5)]
y = [10**y for y in range(0,5)]
plt.plot(x,y)
plt.show()

# %%
plt.semilogx(x,y)
plt.show()

# %%
plt.semilogy(x,y)
plt.show()

# %%
plt.loglog(x,y)
plt.show()

# %%
x= np.arange(-2*np.pi,2*np.pi,0.01)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x,y1,x,y2)
plt.legend(["sinx","$cos(x)$"])
plt.show()

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.legend(["$sin(x)$","$cos(x)$"])
plt.grid()
plt.show()

# %% [markdown]
# #Subplots

# %%
x= np.arange(-2*np.pi,2*np.pi,0.01)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

plt.subplot(1,3,1) #no of row, no of column,  index
plt.plot(x,y1)
plt.subplot(1,3,2) 
plt.plot(x,y2)
plt.subplot(1,3,3) 
plt.plot(x,y3)
plt.grid()
plt.show()

# %%
plt.subplot(3,1,1) #no of row, no of column,  index
plt.plot(x,y1)
plt.title("$sinx$",color='w') #LaTeX
plt.grid()

plt.subplot(3,1,2) 
plt.plot(x,y2)
plt.title("$cosx$",color='w')
plt.grid()

plt.subplot(3,1,3) 
plt.plot(x,y3)
plt.title("$tanx$",color='w')
plt.grid()

plt.show()

# %% [markdown]
# #Bar Graph

# %%
x = np.linspace(0,np.pi,20)
plt.bar(x,np.sin(x))
plt.show()

# %% [markdown]
# #Pi Chart

# %%
x =[5,15,55,25] # if not 100 will adjust values 
plt.pie(x)
plt.show()
